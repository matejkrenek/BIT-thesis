# %%
# %run ./00-config.ipynb
# Out:
# Project root: /home/matejkrenek/fitvut/bit-thesis/project
# SRC path: /home/matejkrenek/fitvut/bit-thesis/project/src
# DATA path: /home/matejkrenek/fitvut/bit-thesis/project/data
# Python sys.path: ['/home/matejkrenek/fitvut/bit-thesis/project/notebooks', '/home/matejkrenek/fitvut/bit-thesis/project/src', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/home/matejkrenek/fitvut/bit-thesis/.venv/lib/python3.12/site-packages']
# Random seed set to 42

# %%
from datasets.defects import CombinedDefectInjector, HoleDefect
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from datasets.defects import CombinedDefectInjector, HoleDefect
#
# ImportError: cannot import name 'CombinedDefectInjector' from 'datasets.defects' (/home/matejkrenek/fitvut/bit-thesis/project/src/datasets/defects/__init__.py)
