# %%
# %load_ext autoreload
# %autoreload 2
# %run ./00-config.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Project root: /home/matejkrenek/fitvut/bit-thesis/project
# SRC path: /home/matejkrenek/fitvut/bit-thesis/project/src
# DATA path: /home/matejkrenek/fitvut/bit-thesis/project/data
# Python sys.path: ['/home/matejkrenek/fitvut/bit-thesis/project/src', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/home/matejkrenek/fitvut/bit-thesis/project/.venv/lib/python3.12/site-packages']

# %%
from datasets.config import DatasetConfig

dataset_config = DatasetConfig()

print(dataset_config.download)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 5
#       1 from datasets.config import DatasetConfig
#       3 dataset_config = DatasetConfig()
# ----> 5 print(dataset_config.download)
#
# AttributeError: 'DatasetConfig' object has no attribute 'download'
